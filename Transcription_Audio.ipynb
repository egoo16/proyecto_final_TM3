# %%
# %pip install noisereduce
# Out:
# Collecting noisereduce
#   Downloading noisereduce-3.0.2-py3-none-any.whl.metadata (14 kB)
# Requirement already satisfied: scipy in c:\users\lotus\anaconda3\lib\site-packages (from noisereduce) (1.11.4)
# Requirement already satisfied: matplotlib in c:\users\lotus\anaconda3\lib\site-packages (from noisereduce) (3.8.0)
# Collecting librosa (from noisereduce)
#   Downloading librosa-0.10.2.post1-py3-none-any.whl.metadata (8.6 kB)
# Requirement already satisfied: numpy in c:\users\lotus\anaconda3\lib\site-packages (from noisereduce) (1.26.4)
# Requirement already satisfied: tqdm in c:\users\lotus\anaconda3\lib\site-packages (from noisereduce) (4.65.0)
# Collecting audioread>=2.1.9 (from librosa->noisereduce)
#   Downloading audioread-3.0.1-py3-none-any.whl.metadata (8.4 kB)
# Requirement already satisfied: scikit-learn>=0.20.0 in c:\users\lotus\anaconda3\lib\site-packages (from librosa->noisereduce) (1.2.2)
# Requirement already satisfied: joblib>=0.14 in c:\users\lotus\anaconda3\lib\site-packages (from librosa->noisereduce) (1.2.0)
# Requirement already satisfied: decorator>=4.3.0 in c:\users\lotus\anaconda3\lib\site-packages (from librosa->noisereduce) (5.1.1)
# Requirement already satisfied: numba>=0.51.0 in c:\users\lotus\anaconda3\lib\site-packages (from librosa->noisereduce) (0.59.0)
# Collecting soundfile>=0.12.1 (from librosa->noisereduce)
#   Downloading soundfile-0.12.1-py2.py3-none-win_amd64.whl.metadata (14 kB)
# Collecting pooch>=1.1 (from librosa->noisereduce)
#   Downloading pooch-1.8.2-py3-none-any.whl.metadata (10 kB)
# Collecting soxr>=0.3.2 (from librosa->noisereduce)
#   Downloading soxr-0.5.0.post1-cp311-cp311-win_amd64.whl.metadata (5.6 kB)
# Requirement already satisfied: typing-extensions>=4.1.1 in c:\users\lotus\anaconda3\lib\site-packages (from librosa->noisereduce) (4.9.0)
# Requirement already satisfied: lazy-loader>=0.1 in c:\users\lotus\anaconda3\lib\site-packages (from librosa->noisereduce) (0.3)
# Requirement already satisfied: msgpack>=1.0 in c:\users\lotus\anaconda3\lib\site-packages (from librosa->noisereduce) (1.0.3)
# Requirement already satisfied: contourpy>=1.0.1 in c:\users\lotus\anaconda3\lib\site-packages (from matplotlib->noisereduce) (1.2.0)
# Requirement already satisfied: cycler>=0.10 in c:\users\lotus\anaconda3\lib\site-packages (from matplotlib->noisereduce) (0.11.0)
# Requirement already satisfied: fonttools>=4.22.0 in c:\users\lotus\anaconda3\lib\site-packages (from matplotlib->noisereduce) (4.25.0)
# Requirement already satisfied: kiwisolver>=1.0.1 in c:\users\lotus\anaconda3\lib\site-packages (from matplotlib->noisereduce) (1.4.4)
# Requirement already satisfied: packaging>=20.0 in c:\users\lotus\anaconda3\lib\site-packages (from matplotlib->noisereduce) (23.1)
# Requirement already satisfied: pillow>=6.2.0 in c:\users\lotus\anaconda3\lib\site-packages (from matplotlib->noisereduce) (10.2.0)
# Requirement already satisfied: pyparsing>=2.3.1 in c:\users\lotus\anaconda3\lib\site-packages (from matplotlib->noisereduce) (3.0.9)
# Requirement already satisfied: python-dateutil>=2.7 in c:\users\lotus\anaconda3\lib\site-packages (from matplotlib->noisereduce) (2.8.2)
# Requirement already satisfied: colorama in c:\users\lotus\anaconda3\lib\site-packages (from tqdm->noisereduce) (0.4.6)
# Requirement already satisfied: llvmlite<0.43,>=0.42.0dev0 in c:\users\lotus\anaconda3\lib\site-packages (from numba>=0.51.0->librosa->noisereduce) (0.42.0)
# Requirement already satisfied: platformdirs>=2.5.0 in c:\users\lotus\anaconda3\lib\site-packages (from pooch>=1.1->librosa->noisereduce) (3.10.0)
# Requirement already satisfied: requests>=2.19.0 in c:\users\lotus\anaconda3\lib\site-packages (from pooch>=1.1->librosa->noisereduce) (2.31.0)
# Requirement already satisfied: six>=1.5 in c:\users\lotus\anaconda3\lib\site-packages (from python-dateutil>=2.7->matplotlib->noisereduce) (1.16.0)
# Requirement already satisfied: threadpoolctl>=2.0.0 in c:\users\lotus\anaconda3\lib\site-packages (from scikit-learn>=0.20.0->librosa->noisereduce) (2.2.0)
# Requirement already satisfied: cffi>=1.0 in c:\users\lotus\anaconda3\lib\site-packages (from soundfile>=0.12.1->librosa->noisereduce) (1.16.0)
# Requirement already satisfied: pycparser in c:\users\lotus\anaconda3\lib\site-packages (from cffi>=1.0->soundfile>=0.12.1->librosa->noisereduce) (2.21)
# Requirement already satisfied: charset-normalizer<4,>=2 in c:\users\lotus\anaconda3\lib\site-packages (from requests>=2.19.0->pooch>=1.1->librosa->noisereduce) (2.0.4)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\lotus\anaconda3\lib\site-packages (from requests>=2.19.0->pooch>=1.1->librosa->noisereduce) (3.4)
# Requirement already satisfied: urllib3<3,>=1.21.1 in c:\users\lotus\anaconda3\lib\site-packages (from requests>=2.19.0->pooch>=1.1->librosa->noisereduce) (2.0.7)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\lotus\anaconda3\lib\site-packages (from requests>=2.19.0->pooch>=1.1->librosa->noisereduce) (2024.6.2)
# Downloading noisereduce-3.0.2-py3-none-any.whl (22 kB)
# Downloading librosa-0.10.2.post1-py3-none-any.whl (260 kB)
#    ---------------------------------------- 0.0/260.1 kB ? eta -:--:--
#    ------- ------------------------------- 51.2/260.1 kB 871.5 kB/s eta 0:00:01
#    ---------------------- ----------------- 143.4/260.1 kB 1.4 MB/s eta 0:00:01
#    ---------------------------------------  256.0/260.1 kB 1.7 MB/s eta 0:00:01
#    ---------------------------------------- 260.1/260.1 kB 1.8 MB/s eta 0:00:00
# Downloading audioread-3.0.1-py3-none-any.whl (23 kB)
# Downloading pooch-1.8.2-py3-none-any.whl (64 kB)
#    ---------------------------------------- 0.0/64.6 kB ? eta -:--:--
#    ---------------------------------------- 64.6/64.6 kB 3.4 MB/s eta 0:00:00
# Downloading soundfile-0.12.1-py2.py3-none-win_amd64.whl (1.0 MB)
#    ---------------------------------------- 0.0/1.0 MB ? eta -:--:--
#    ---- ----------------------------------- 0.1/1.0 MB 3.6 MB/s eta 0:00:01
#    --------- ------------------------------ 0.2/1.0 MB 2.5 MB/s eta 0:00:01
#    -------------- ------------------------- 0.4/1.0 MB 2.5 MB/s eta 0:00:01
#    ------------------- -------------------- 0.5/1.0 MB 2.6 MB/s eta 0:00:01
#    ------------------------ --------------- 0.6/1.0 MB 2.6 MB/s eta 0:00:01
#    ----------------------------- ---------- 0.7/1.0 MB 2.8 MB/s eta 0:00:01
#    ---------------------------------- ----- 0.9/1.0 MB 2.6 MB/s eta 0:00:01
#    -------------------------------------- - 1.0/1.0 MB 2.7 MB/s eta 0:00:01
#    ---------------------------------------- 1.0/1.0 MB 2.7 MB/s eta 0:00:00
# Downloading soxr-0.5.0.post1-cp311-cp311-win_amd64.whl (166 kB)
#    ---------------------------------------- 0.0/166.7 kB ? eta -:--:--
#    ---------------------------------- ----- 143.4/166.7 kB 2.8 MB/s eta 0:00:01
#    ---------------------------------------- 166.7/166.7 kB 3.3 MB/s eta 0:00:00
# Installing collected packages: soxr, audioread, soundfile, pooch, librosa, noisereduce
# Successfully installed audioread-3.0.1 librosa-0.10.2.post1 noisereduce-3.0.2 pooch-1.8.2 soundfile-0.12.1 soxr-0.5.0.post1
# Note: you may need to restart the kernel to use updated packages.

# %%
import noisereduce as nr
import numpy as np
from scipy.io import wavfile
from pydub import AudioSegment
import speech_recognition as sr
import io
import spacy
import spacy.cli
from spacy.matcher import PhraseMatcher
from sklearn.feature_extraction.text import TfidfVectorizer
import re

# %%
import keras
print(keras.__version__)
# Out:
# 3.5.0

# %%
def reduce_noise(audio_segment):
    samples = np.array(audio_segment.get_array_of_samples())
    rate = audio_segment.frame_rate
    reduced_noise = nr.reduce_noise(y=samples, sr=rate)
    return AudioSegment(
        reduced_noise.tobytes(), 
        frame_rate=rate, 
        sample_width=audio_segment.sample_width, 
        channels=audio_segment.channels
    )

# %%
def split_audio(audio_file, chunk_length_ms=60000):
    audio = AudioSegment.from_file(audio_file)
    chunks = [audio[i:i + chunk_length_ms] for i in range(0, len(audio), chunk_length_ms)]
    return chunks

# %%
def transcribe_audio(audio_segment):
    recognizer = sr.Recognizer()
    with io.BytesIO(audio_segment.export(format="wav").read()) as audio_file:
        audio_data = sr.AudioFile(audio_file)
        with audio_data as source:
            audio = recognizer.record(source)
        try:
            text = recognizer.recognize_google(audio, language="es-ES")
            return text
        except sr.UnknownValueError:
            return "No se pudo entender el audio"
        except sr.RequestError:
            return "Error al solicitar el servicio de reconocimiento de voz"

# %%
audio_file = "test/TestXep1.wav"
chunks = split_audio(audio_file)
full_text = ""

# %%
for chunk in chunks:
    reduced_chunk = reduce_noise(chunk)
    text = transcribe_audio(reduced_chunk)
    full_text += text + " "

print(full_text)
# Out:
# perfecto señoras y señores acá el partido arranca arranca el partido señores señores ya estamos en el juego ya se juega la gran final el equipo de la antigua va por el Campeonato lleva una ventaja lleva una buena ventaja de 2 por 0 pero tiene enfrente a un equipo que también está acostumbrado a ser campeón y buscará llegar a su sexta luna que no quiere no quiere no quiere no quiere el equipo del semáforo Camposeco aquí la tiene Moreira Moreira tiene la pelota la mete para González aquí estamos somos el Escuadrón deportivo con toda la pasión de deportes sigan dejando su comentario sigan dejando siga participando porque estaremos leyendo a todos saluditos para Cristian José Saluditos ahí están conectados en YouTube Muchas gracias muchas gracias por reportarse aquí está la pelota que le pertenece al equipo de antigua Guatemala en tiro libre tiro libre tiro libre tiro libre peligroso que le pertenece al 4 de Xelajú Mario Camposeco Aquí está el equipo de antigua Guatemala que quiere que quiere el primer tanto del partido gracias por todo gracias por terminar antigua viene el remate Aquí está el primero el remate va a llegar el Arquero pero bien cortaron saca la saca del equipo de Mario Camposeco llega el Arquero se quedó con la pelota iba a hacer pelota de la saqué de arco José Calderón tiene la pelotita y va a salir jugando desde el fondo para el equipo de Xelajú Mario Camposeco Aquí está el Arquero ya oficialmente espectacular pero el ambiente maravilloso que el Mario Camposeco aquí vendrá a cobrar un saque de Colonia cobró el Arquero súper chivo el servicio que viene el árbitro a tres cuartos de cancha para Jacob para el equipo de antigua Guatemala contra el equipo de fútbol con Cristian Hernández aquí Viene saliendo del equipo de activo de Guatemala va quedando para el equipo de Ciudad Juárez Campos sacó Esta es buena para hacer la cruz aquí la tiene bien Maynor de John Mayer tiene la pelota pero llega barriendo la saca la antigua balón para afuera y hacer pelota que le pertenece la pila pero es para ti Cuál es el árbitro vamos aquí está qué le pertenece al equipo de antigua Guatemala bien antigua viene sobre la derecha aquí viene presionando muy bien el futbolista brasileño para el equipo de zona cuyo campo seco y aquí arrancaba el servicio mete la pelota para allá corta el equipo de antigua que sale con Christian Hernández Hernández y la pelota la pone por derecha viene Tito Carlos Mejía el huila Mejía cambia la pelota sobre el costado izquierdo aquí arranca lateral derecho tiene que venga que ingresaba metiendo el zapatazo buena pelota viene el arco el servicio que va para afuera Mientras más buena saca aplaude la banca de comunicaciones Así que mi querido Coyote vamos a ver algunos Saluditos a la gente que va llegando allá al escuadrón deportivo oficial seguimos leyendo interactuando con todos los amigos que nos acompañan a través del escuadrón deportivo oficial Ahí está la transmisión totalmente en vivo amigos de toda la transmisión estaba atacando aquí conmigo al costado de la derecha que nos roba antigua por ahí su contragolpe con espacios otra vez ataca antiguamente Hasta que el equipo de Antioquia para el equipo nacional Cuándo viene saliendo señoras y señores aquí estamos con todo el Escuadrón deportivo a través del comandante pero arranca el deporte aquí viene el equipo de Xelajú Mario Camposeco la viene peleando desde la media cancha Kennedy tierras Kennedy Gutiérrez cambia y juega hacia atrás y desde el fondo tiene 14 y la pelota sobre el equipo de Sebastián Mario Camposeco que quiere encontrar alguna posibilidad Cardoza tiene el servicio allá por la derecha el equipo de Xelajú Mario Camposeco número 14 para Javier González Javier González primer servicio largo está parece buena pero ya llegué de la saga del equipo de antigua Guatemala y mandó la pelota para afuera y va hacer saqué de puerta saque de arco para el equipo de antigua Guatemala que tiene la serie que tiene la serie 2-0 a su favor y aquí viene el Arquer ...

# %%
audio_file2 = "test/TestXep2.wav"
chunks2 = split_audio(audio_file2)
full_text2 = ""

# %%
for chunk in chunks2:
    reduced_chunk2 = reduce_noise(chunk)
    text2 = transcribe_audio(reduced_chunk2)
    full_text2 += text2 + " "

print(full_text2)
# Out:
# Sí pero soy el deporte se arranca el partido ante ti para tirar el Arquero se quedó con la pelota el Arquero antigueño Linares tiene la pelota hacia arriba hacia la Julia arrancó con todos en la primera acercamiento primero en Mateo le pegó azul y la pita Mejía iba pegando al palo derecho para el Arquero estuvo atento y aquí está Xelajú Mario Camposeco que viene al contraataque pero ya recupera el conjunto del árbitro dice que es pelota para el equipo de antiguo en saque lateral saque de banda para la antigua señoras y señores saque de banda para el equipo de antigua aquí vienen los Panzas Verdes los Panzas Verdes dos Panzas Verdes el servicio que va a dar algo largo largo aquí ataque antigua pero hoy pasamos atorado Así que vendrás con Mario Camposeco a cobrar saqué de puerta saque de puerta que le pertenece a los Súper chivos saque de puerta para se bajó que va a ir con todo a buscar el gol del empate 45 minutos ahora 44 para que se la jugó puede empatar ese uno que tiene contra el servicio que va largo para el conjunto de antiguo pero ya en recuperación la balón para afuera y va a hacer un saque de banda para el equipo de antigua saca demanda por el costado de la derecha Dos variantes de la antigua Santi si está en la cancha Y también Alexander Delgado Aquí está el equipo panza versus desde la media cancha avanzando dentro de la cruz trabajando muy bien en la zona baja vuelve el equipo de antigua la pelota que está jugando a la derecha vamos a ver a la gente de escuadrón deportivo en Facebook Muchas gracias por seguir participando para tratarlo dice Saludos desde Cancún Quintana Roo México y Quién ganará jugó Andrea dice Saludos a pochi desde reuma mucha gente apoyándose bajo un coyote hay mucha gente una 80 por ciento dónde van se la juventud 20% antigua que pese así la afición así la gente en la transmisión los invitamos a compartir estamos cerca de las primeras En esta segunda mitad que arrancó con todos se bajó y tuvo su primera llegada con Maynor de Joker se mandó zurdazo pero se fue desviado de Braulio de la portería que Define Bronco Linares ahora ataques en la segunda vez eh una vez más ataques a la jugabilidad González viene por la derecha estaba por línea final el árbitro dice que saque de banda para el equipo de antigua Guatemala para sacar para atrás antigueños aquí viene José José con la pelota sobre la izquierda en salida del equipo de antigua pero lleva está presionando bien arriba eso me gusta está presionando bien arriba como tiene que ser un equipo que va a poner la misma montada saque de banda aquí arranca Javier González para Sebastián saque lateral para los chivos sobre la derecha cerca de la portería de finales aquí con unos chivos el arco que dice que el último y tocar fue ayer Así que va a ser el saque de puerta saqué de puerta saque de puerta y se enoja se enoja Óscar Villa pedía que es de esquina en el arco que no lo concede por lo tanto va a ser saque de arco para antigua tiros de esquinas tiro tiro de esquina si los dos tiros de esquina tiro de esquina panche bajó Mario Camposeco por la derecha sobre el costado derecho apretarse los cinco archivos en el centro Juan Arquero puede venir el contraste pero ya se perdió la en peligro de los hombres lesionados el árbitro que tiene el fuego un hombre por el equipo de Sebastián Camposeco Llano por antiguo Así que aprovechamos para mañana en comentarios la gente Coyote saludamos a Mario Castañeda excelente transmisión Saludos cordiales desde Los Ángeles California Rolando guantes Perico vamos en la Marcos galán Saludos desde policía amigos Buena transmisión Cruz Morales vamos Sheila desde antigua Guatemala vamos a hacer la la temporada José Manuel Cómo va el marcador 1 a 0 canales la cuerda global está ganando antigua dos a uno uno más para encuadrar la serie a estuardo Pérez dice antigua Pedro Hernández vamos y bebés Saludos desde Nueva Jersey Miguel Romero Saludos desde Zacapa vamos antigua ahí está la gente interactuando Ingrid todavía no se recuperan  ...

# %% [markdown]
# ## Guardamos las transcripciones

# %%
with open("primer_tiempo.txt", "w", encoding="utf-8") as file1:
    file1.write(full_text)

with open("segundo_tiempo.txt", "w", encoding="utf-8") as file2:
    file2.write(full_text2)

print("Transcripciones guardadas correctamente.")
# Out:
# Transcripciones guardadas correctamente.

# %% [markdown]
# ## Leemos las transcripciones

# %%
with open("primer_tiempo.txt", "r", encoding="utf-8") as file1:
    time1 = file1.read()

time1
# Out:
# 'perfecto señoras y señores acá el partido arranca arranca el partido señores señores ya estamos en el juego ya se juega la gran final el equipo de la antigua va por el Campeonato lleva una ventaja lleva una buena ventaja de 2 por 0 pero tiene enfrente a un equipo que también está acostumbrado a ser campeón y buscará llegar a su sexta luna que no quiere no quiere no quiere no quiere el equipo del semáforo Camposeco aquí la tiene Moreira Moreira tiene la pelota la mete para González aquí estamos somos el Escuadrón deportivo con toda la pasión de deportes sigan dejando su comentario sigan dejando siga participando porque estaremos leyendo a todos saluditos para Cristian José Saluditos ahí están conectados en YouTube Muchas gracias muchas gracias por reportarse aquí está la pelota que le pertenece al equipo de antigua Guatemala en tiro libre tiro libre tiro libre tiro libre peligroso que le pertenece al 4 de Xelajú Mario Camposeco Aquí está el equipo de antigua Guatemala que quiere que quiere el primer tanto del partido gracias por todo gracias por terminar antigua viene el remate Aquí está el primero el remate va a llegar el Arquero pero bien cortaron saca la saca del equipo de Mario Camposeco llega el Arquero se quedó con la pelota iba a hacer pelota de la saqué de arco José Calderón tiene la pelotita y va a salir jugando desde el fondo para el equipo de Xelajú Mario Camposeco Aquí está el Arquero ya oficialmente espectacular pero el ambiente maravilloso que el Mario Camposeco aquí vendrá a cobrar un saque de Colonia cobró el Arquero súper chivo el servicio que viene el árbitro a tres cuartos de cancha para Jacob para el equipo de antigua Guatemala contra el equipo de fútbol con Cristian Hernández aquí Viene saliendo del equipo de activo de Guatemala va quedando para el equipo de Ciudad Juárez Campos sacó Esta es buena para hacer la cruz aquí la tiene bien Maynor de John Mayer tiene la pelota pero llega barriendo la saca la antigua balón para afuera y hacer pelota que le pertenece la pila pero es para ti Cuál es el árbitro vamos aquí está qué le pertenece al equipo de antigua Guatemala bien antigua viene sobre la derecha aquí viene presionando muy bien el futbolista brasileño para el equipo de zona cuyo campo seco y aquí arrancaba el servicio mete la pelota para allá corta el equipo de antigua que sale con Christian Hernández Hernández y la pelota la pone por derecha viene Tito Carlos Mejía el huila Mejía cambia la pelota sobre el costado izquierdo aquí arranca lateral derecho tiene que venga que ingresaba metiendo el zapatazo buena pelota viene el arco el servicio que va para afuera Mientras más buena saca aplaude la banca de comunicaciones Así que mi querido Coyote vamos a ver algunos Saluditos a la gente que va llegando allá al escuadrón deportivo oficial seguimos leyendo interactuando con todos los amigos que nos acompañan a través del escuadrón deportivo oficial Ahí está la transmisión totalmente en vivo amigos de toda la transmisión estaba atacando aquí conmigo al costado de la derecha que nos roba antigua por ahí su contragolpe con espacios otra vez ataca antiguamente Hasta que el equipo de Antioquia para el equipo nacional Cuándo viene saliendo señoras y señores aquí estamos con todo el Escuadrón deportivo a través del comandante pero arranca el deporte aquí viene el equipo de Xelajú Mario Camposeco la viene peleando desde la media cancha Kennedy tierras Kennedy Gutiérrez cambia y juega hacia atrás y desde el fondo tiene 14 y la pelota sobre el equipo de Sebastián Mario Camposeco que quiere encontrar alguna posibilidad Cardoza tiene el servicio allá por la derecha el equipo de Xelajú Mario Camposeco número 14 para Javier González Javier González primer servicio largo está parece buena pero ya llegué de la saga del equipo de antigua Guatemala y mandó la pelota para afuera y va hacer saqué de puerta saque de arco para el equipo de antigua Guatemala que tiene la serie que tiene la serie 2-0 a su favor y aquí viene el Arque ...

# %%
with open("segundo_tiempo.txt", "r", encoding="utf-8") as file2:
    time2 = file2.read()
time2
# Out:
# "Sí pero soy el deporte se arranca el partido ante ti para tirar el Arquero se quedó con la pelota el Arquero antigueño Linares tiene la pelota hacia arriba hacia la Julia arrancó con todos en la primera acercamiento primero en Mateo le pegó azul y la pita Mejía iba pegando al palo derecho para el Arquero estuvo atento y aquí está Xelajú Mario Camposeco que viene al contraataque pero ya recupera el conjunto del árbitro dice que es pelota para el equipo de antiguo en saque lateral saque de banda para la antigua señoras y señores saque de banda para el equipo de antigua aquí vienen los Panzas Verdes los Panzas Verdes dos Panzas Verdes el servicio que va a dar algo largo largo aquí ataque antigua pero hoy pasamos atorado Así que vendrás con Mario Camposeco a cobrar saqué de puerta saque de puerta que le pertenece a los Súper chivos saque de puerta para se bajó que va a ir con todo a buscar el gol del empate 45 minutos ahora 44 para que se la jugó puede empatar ese uno que tiene contra el servicio que va largo para el conjunto de antiguo pero ya en recuperación la balón para afuera y va a hacer un saque de banda para el equipo de antigua saca demanda por el costado de la derecha Dos variantes de la antigua Santi si está en la cancha Y también Alexander Delgado Aquí está el equipo panza versus desde la media cancha avanzando dentro de la cruz trabajando muy bien en la zona baja vuelve el equipo de antigua la pelota que está jugando a la derecha vamos a ver a la gente de escuadrón deportivo en Facebook Muchas gracias por seguir participando para tratarlo dice Saludos desde Cancún Quintana Roo México y Quién ganará jugó Andrea dice Saludos a pochi desde reuma mucha gente apoyándose bajo un coyote hay mucha gente una 80 por ciento dónde van se la juventud 20% antigua que pese así la afición así la gente en la transmisión los invitamos a compartir estamos cerca de las primeras En esta segunda mitad que arrancó con todos se bajó y tuvo su primera llegada con Maynor de Joker se mandó zurdazo pero se fue desviado de Braulio de la portería que Define Bronco Linares ahora ataques en la segunda vez eh una vez más ataques a la jugabilidad González viene por la derecha estaba por línea final el árbitro dice que saque de banda para el equipo de antigua Guatemala para sacar para atrás antigueños aquí viene José José con la pelota sobre la izquierda en salida del equipo de antigua pero lleva está presionando bien arriba eso me gusta está presionando bien arriba como tiene que ser un equipo que va a poner la misma montada saque de banda aquí arranca Javier González para Sebastián saque lateral para los chivos sobre la derecha cerca de la portería de finales aquí con unos chivos el arco que dice que el último y tocar fue ayer Así que va a ser el saque de puerta saqué de puerta saque de puerta y se enoja se enoja Óscar Villa pedía que es de esquina en el arco que no lo concede por lo tanto va a ser saque de arco para antigua tiros de esquinas tiro tiro de esquina si los dos tiros de esquina tiro de esquina panche bajó Mario Camposeco por la derecha sobre el costado derecho apretarse los cinco archivos en el centro Juan Arquero puede venir el contraste pero ya se perdió la en peligro de los hombres lesionados el árbitro que tiene el fuego un hombre por el equipo de Sebastián Camposeco Llano por antiguo Así que aprovechamos para mañana en comentarios la gente Coyote saludamos a Mario Castañeda excelente transmisión Saludos cordiales desde Los Ángeles California Rolando guantes Perico vamos en la Marcos galán Saludos desde policía amigos Buena transmisión Cruz Morales vamos Sheila desde antigua Guatemala vamos a hacer la la temporada José Manuel Cómo va el marcador 1 a 0 canales la cuerda global está ganando antigua dos a uno uno más para encuadrar la serie a estuardo Pérez dice antigua Pedro Hernández vamos y bebés Saludos desde Nueva Jersey Miguel Romero Saludos desde Zacapa vamos antigua ahí está la gente interactuando Ingrid todavía no se recuperan ...
